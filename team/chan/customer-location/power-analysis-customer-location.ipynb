# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import matplotlib.pyplot as plt 
import seaborn as sns 
import pandas as pd
import numpy as np
from scipy.stats import norm
from dataclasses import dataclass

from utils import *
from config import *

# %% [markdown]
# ## How does this work?
#
# This notebook executes a power analysis when the goal is to run discovery / elasticities tests for customer areas. Test setup is based on what was shared in the [Pricing Community VII](https://docs.google.com/presentation/d/17DcFaQTIVhFMLIZcWUR7lKg6VU-bidehiqQxXSUGJxQ/edit) regarding customer location. Since the analysis is not at the city level but rather at areas, we need to ensure that all areas must meet the sample size.
#
# The methodology here proposes an algorithm that takes area shapes, some session data and outputs a smaller, consolidated list of areas that should be analyzed together. The algorithm works assuming that if the smallest area, defined by the number of users making sessions, meets the sample size, all bigger areas will too. If an area does not meet the sample size, it must be merged with another area. The step-by-step process is the following:
#
# - Load required data from BQ -> area shapes + session, conversion data at the user level + area indicator
# - Initialize the tests parameters (n_variants, mde, alpha, power) plus a area mapping
#     - The area mapping is extremely important. It keeps a log of which area should be merged with another one. For example, at iteration 0 we got the following mapping {"A":"A", "B":"B", "C":"C"}.\
#       In the first iteration, it was decided that area "C" should be added to "A". thus, the new mapping is: {"A":"A", "B":"B", "C":"A"}.
# - aggregate user level data to find the smallest area
# - Using the aggregated data, find the smallest neighbor for each area.
# - Calculate the required sample size for the intented MDE and compare it to the number of users in the area.
#   - if the area has more user. Amazing, algorithm will stop.
#   - otherwise, merge the area to their smallest neighbor.
#     - In the case the area doesn't have any neighbor, it will be merged with the next overall smallest area.
# - Update the area mappings
#
# Repeat until the algorithm has managed to find all areas that meet the sample size or it has exhausted all iterations.

# %% [markdown]
# ### TO-DO
# - Parametrize sql arguments to allow different inputs.
# - Wrap the while in a function or what?
# - Persist aggregated shapes (BQ table, csv?)

# %% [markdown]
# # Code

# %% [markdown]
# ## Load data

# %%
connector = Connector(**BIGQUERY_CONFIG)

# %%
detail_data = connector.get_df_from_query(
    open("queries/cvr-per-area.sql", "r").read()
)

area_shapes = (
    connector
    .get_df_from_query(open("queries/area-shapes.sql", "r").read())
    .pipe(convert_to_geopandas, "area_shape")
    .drop(columns=["area_shape"])
)
# Out:
# Job ID c03dbdd7-8177-46e1-ba53-f6796ce5c9e7 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 6b9b4da4-a713-46b7-bdf8-0b7c03b66963 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|

# %% [markdown]
# ##  Utils

# %%
@dataclass
class DeltaParameters:
    """Holds the parameters relevant to delta method variance.
    more info here: https://arxiv.org/abs/2305.16459

    As a general definition
    u_s -> mean of sessions per user
    var_s -> variance of avg sessions per user
    u_n -> mean of transactions per user
    var_n -> variance of avg transactions per user
    covar_sn -> coviriance between transactions and sessions
    """
    u_s:float
    u_n:float 
    var_s:float 
    var_n:float 
    covar_sn:float 


@dataclass
class PowerInputs:
    """Class to hold default inputs for power analysis. 
    As a note, MDE must be ABSOLUTE
    """
    mde:float 
    alpha:float = 0.05
    power:float = 0.8
    

def aggregate_detail_data(df:pd.DataFrame, session_col:str, conversion_col:str) -> DeltaParameters:
    """Take a dataframe that holds information at the randomization level (e.g user) and 
    calculate the variance/averages parameters used in the delta method.

    Args:
        df (pd.DataFrame): _description_
        session_col (str): _description_
        conversion_col (str): _description_

    Returns:
        DeltaParameters: _description_
    """
    params =  {
            "u_s": df[session_col].mean()
            , "u_n": df[conversion_col].mean()
            , "var_s": df[session_col].var()
            , "var_n":df[conversion_col].var()
            , "covar_sn":df[session_col].cov(df[conversion_col])
        }
    return DeltaParameters(**params)

def calculate_h(params:DeltaParameters) -> float:
    """Calculate the factor h which is a correction of the variance for ratio metrics 
    used in the delta method. More info here https://arxiv.org/abs/2305.16459

    Args:
        params (DeltaParameters): _description_

    Returns:
        float: _description_
    """
    denom = pow(params.u_n,2)
    num = params.var_s - 2*params.covar_sn*(params.u_s/params.u_n) + params.var_n* (pow(params.u_s,2) / pow(params.u_n,2))
    return num / denom

def calculate_sample_size(delta_params: DeltaParameters, power_inputs:PowerInputs) -> float:
    """Calculate number of users (sample size) using the delta method.
    Method details are in this paper: https://arxiv.org/abs/2305.16459

    As a summary, the delta method uses a corrected formula to get
    the correct variance in the case sessions are correlated. This correlation usually happens
    experiment randomizes on users but CVR is on session level.

    Args:
        delta_params (DeltaParameters): _description_
        power_inputs (PowerInputs): _description_

    Returns:
        float: _description_
    """
    h = calculate_h(delta_params)
    k = ( 2 * h * pow(abs(norm.ppf(power_inputs.alpha/2)) + norm.ppf(power_inputs.power), 2) ) / pow(power_inputs.mde, 2)
    return k


# test function
# params = DeltaParameters(u_s=2.6, u_n=4.2, var_s=10.3, var_n=12.7, covar_sn=10.1)
# power_inputs = PowerInputs(mde=0.05)
# calculate_sample_size(params, power_inputs)

# %%
def update_area_mappings(area_mapping:dict, current_area:str, next_area:str) -> dict[str, str]:
    """This function update the mapping between the area and the group they get added to.
    The idea of the mapping is to change the value of a given key. At the first iteration,
    key and value are the same, i.e, the area name. As iterations goes on an smaller areas
    get joined to other, the value will change to reference the area they're added to. 

    For example, at iteration 0 we got the following mapping {"A":"A", "B":"B", "C":"C"}.
    In the first iteration, it was decided that area "C" should be added to add, this function
    should return the following dictionary: {"A":"A", "B":"B", "C":"A"}.

    Args:
        area_mapping (dict): _description_
        current_area (str): _description_
        next_area (str): _description_

    Returns:
        dict[str, list[str]]: _description_
    """
    # replace the current key value for the next area
    area_mapping[current_area] = next_area
    return {key:val.replace(current_area, next_area) for key, val in area_mapping.items()}


def aggregate_user_data_per_area(df: pd.DataFrame) -> pd.DataFrame:
        """This functions aggregate the input data, which is on user level
        and calculate aggregated metrics at the area level

        Args:
            df (pd.DataFrame): _description_
            agg_col (str): _description_

        Returns:
            pd.DataFrame: _description_
        """
        return (
                df
                .groupby( ["area_map"], as_index=False)
                .agg(
                        avg_sessions = ("n_sessions", "mean")
                        ,  avg_conversions = ("n_conversions", "mean")
                        ,  total_session = ("n_sessions", "sum")
                        ,  total_conversion = ("n_conversions", "sum")
                        ,  n_users = ("perseus_client_id", "count")
                )
                .sort_values(by="n_users", ascending=True)
        )

def aggregate_shape_data_per_area(df:gpd.GeoDataFrame, area_mapping:dict[str,str]) -> gpd.GeoDataFrame:
        """This function is used to obtain the combined polygon shape of areas that has been merged.
        The area_mapping argument keeps track of such mapping from the original/detailed areas to the 
        combined ones. The result is another geopandas dataframe but with only the combined areas names and shapes

        Args:
            df (gpd.GeoDataFrame): _description_
            area_mapping (dict[str,str]): _description_

        Returns:
            gpd.GeoDataFrame: _description_
        """
        return (
                df
                .assign(
                        area_map = lambda df: df.area_name.map(area_mapping)
                )
                .dissolve(by="area_map", aggfunc="sum")
                .reset_index()
        )

def get_neighbors_from_shapes(shapes_df:gpd.GeoDataFrame, area_df:pd.DataFrame) -> pd.DataFrame:
        """This functions calculate the smallest neighbor for each area. A neighbor is defined as two polygons
        sharing a common border. Smallest is defined in terms of number of users each area has.

        Args:
            shapes_df (gpd.GeoDataFrame): _description_
            area_df (pd.DataFrame): _description_

        Returns:
            pd.DataFrame: _description_
        """

        return (
                shapes_df
                .sjoin(shapes_df, how="left", predicate="touches")
                [["area_map_left", "area_map_right"]]
                .rename(columns={"area_map_left":"area_map", "area_map_right":"neighbor_name"})
                .merge(area_df, left_on="neighbor_name", right_on="area_map", suffixes=(None, "_y"))
                [["area_map", "neighbor_name", "n_users"]]
                .pipe(row_number, partition_cols=["area_map"], sort_col="n_users", col_name="neighbor_rank")
        )

# %% [markdown]
# ## Workflow

# %%
area_mapping = {x:x for x in area_shapes.area_name.unique()}
power_inputs = PowerInputs(mde=0.05)
n_variants = 2

it_df = (
    detail_data
    .copy()
)

it_shapes = (
    area_shapes
    .copy()
)

i = 0
n_it = 100

while i < n_it:
    # update data with current mapping
    it_df = (it_df 
            .assign(area_map = lambda df: df.area_name.map(area_mapping))  
    )

    agg_data = (
        it_df
        .pipe(aggregate_user_data_per_area)
    )

    agg_shapes = (
        it_shapes
        .pipe(aggregate_shape_data_per_area, area_mapping)
    )

    neighbors = (
            agg_shapes
            .pipe(get_neighbors_from_shapes, agg_data)
    )

    # calculate sample size of the current area
    # upadte mapping if needed

    current_area = (
        agg_data
        .iloc[0]
    )

    current_area_params = (
        it_df
        .query(f"area_map=='{current_area.area_map}'")
        .pipe(aggregate_detail_data, "n_sessions", "n_conversions")
    )

    sample_size = calculate_sample_size(current_area_params, power_inputs)

    if sample_size > current_area.n_users / n_variants:
        area_neighbors = (
            neighbors
            .query(f"area_map=='{current_area.area_map}'")
            .sort_values(by=["neighbor_rank"])
        )
        if area_neighbors.empty:
            # in case the current area dont have neighbor, we use the overall next smalles
            smallest_neighbor = agg_data.iloc[1].area_map
        else:
            smallest_neighbor = area_neighbors.iloc[0].neighbor_name

        area_mapping = update_area_mappings(area_mapping, current_area.area_map, smallest_neighbor)
    
    else:
        print("Sample size has been reached!")
        break
    
    print(f"iteration {i}")
    print("Current Smallest Area")
    print(current_area)
    print()

    print(f"Sample size: {sample_size:.0f}, Area size: {current_area.n_users}")
    print(f"Area {current_area.area_map} to be merged with next neighbor: {smallest_neighbor}")
    print(f"{len(set(area_mapping.values()))} unique areas")
    print()

    i += 1
# Out:
# iteration 0
# Current Smallest Area
# area_map              Adalar
# avg_sessions        1.016129
# avg_conversions     0.112903
# total_session             63
# total_conversion           7
# n_users                   62
# Name: 0, dtype: object
#
# Sample size: 4086068, Area size: 62
# Area Adalar to be merged with next neighbor: Çatalca
# 38 unique areas
#
# iteration 1
# Current Smallest Area
# area_map             Çatalca
# avg_sessions        1.016575
# avg_conversions     0.160221
# total_session            184
# total_conversion          29
# n_users                  181
# Name: 32, dtype: object
#
# Sample size: 1344558, Area size: 181
# Area Çatalca to be merged with next neighbor: Silivri
# 37 unique areas
#
# iteration 2
# Current Smallest Area
# area_map                Şile
# avg_sessions        1.014563
# avg_conversions     0.228155
# total_session            209
# total_conversion          47
# n_users                  206
# Name: 35, dtype: object
#
# Sample size: 427413, Area size: 206
# Area Şile to be merged with next neighbor: Çekmekoy
# 36 unique areas
#
# iteration 3
# Current Smallest Area
# area_map            Çekmekoy
# avg_sessions        2.264202
# avg_conversions     0.848328
# total_session          16660
# total_conversion        6242
# n_users                 7358
# Name: 32, dtype: object
#
# Sample size: 62335, Area size: 7358
# Area Çekmekoy to be merged with next neighbor: Beykoz
# 35 unique areas
#
# iteration 4
# Current Smallest Area
# area_map             Silivri
# avg_sessions        2.309931
# avg_conversions     0.876174
# total_session          22143
# total_conversion        8399
# n_users                 9586
# Name: 27, dtype: object
#
# Sample size: 52452, Area size: 9586
# Area Silivri to be merged with next neighbor: Arnavutkoy
# 34 unique areas
#
# iteration 5
# Current Smallest Area
# area_map            Güngören
# avg_sessions        2.232219
# avg_conversions     0.742997
# total_session          34586
# total_conversion       11512
# n_users                15494
# Name: 18, dtype: object
#
# Sample size: 99986, Area size: 15494
# Area Güngören to be merged with next neighbor: Esenler
# 33 unique areas
#
# iteration 6
# Current Smallest Area
# area_map            Sultanbeyli
# avg_sessions            2.21363
# avg_conversions        0.661027
# total_session             37158
# total_conversion          11096
# n_users                   16786
# Name: 26, dtype: object
#
# Sample size: 148297, Area size: 16786
# Area Sultanbeyli to be merged with next neighbor: Sancaktepe
# 32 unique areas
#
# iteration 7
# Current Smallest Area
# area_map            Bayrampaşa
# avg_sessions          2.344697
# avg_conversions       0.814888
# total_session            43813
# total_conversion         15227
# n_users                  18686
# Name: 6, dtype: object
#
# Sample size: 76835, Area size: 18686
# Area Bayrampaşa to be merged with next neighbor: Gaziosmanpaşa
# 31 unique areas
#
# iteration 8
# Current Smallest Area
# area_map            Sultangazi
# avg_sessions          2.221431
# avg_conversions       0.693317
# total_session            44011
# total_conversion         13736
# n_users                  19812
# Name: 25, dtype: object
#
# Sample size: 117450, Area size: 19812
# Area Sultangazi to be merged with next neighbor: Esenler
# 30 unique areas
#
# iteration 9
# Current Smallest Area
# area_map            Arnavutkoy
# avg_sessions          2.184107
# avg_conversions       0.762279
# total_session            48070
# total_conversion         16777
# n_users                  22009
# Name: 0, dtype: object
#
# Sample size: 75097, Area size: 22009
# Area Arnavutkoy to be merged with next neighbor: Basaksehir
# 29 unique areas
#
# iteration 10
# Current Smallest Area
# area_map              Beykoz
# avg_sessions        2.543967
# avg_conversions     0.973066
# total_session          70272
# total_conversion       26879
# n_users                27623
# Name: 6, dtype: object
#
# Sample size: 53401, Area size: 27623
# Area Beykoz to be merged with next neighbor: Üsküdar
# 28 unique areas
#
# iteration 11
# Current Smallest Area
# area_map            Bağcılar
# avg_sessions        2.266964
# avg_conversions      0.67031
# total_session          70727
# total_conversion       20913
# n_users                31199
# Name: 5, dtype: object
#
# Sample size: 146808, Area size: 31199
# Area Bağcılar to be merged with next neighbor: Bahçelievler
# 27 unique areas
#
# iteration 12
# Current Smallest Area
# area_map               Tuzla
# avg_sessions         2.50212
# avg_conversions     0.928277
# total_session          82610
# total_conversion       30648
# n_users                33016
# Name: 22, dtype: object
#
# Sample size: 66256, Area size: 33016
# Area Tuzla to be merged with next neighbor: Pendik
# 26 unique areas
#
# iteration 13
# Current Smallest Area
# area_map             Avcılar
# avg_sessions        2.560176
# avg_conversions     0.951276
# total_session          86068
# total_conversion       31980
# n_users                33618
# Name: 1, dtype: object
#
# Sample size: 63588, Area size: 33618
# Area Avcılar to be merged with next neighbor: Beylikduzu
# 25 unique areas
#
# iteration 14
# Current Smallest Area
# area_map            Zeytinburnu
# avg_sessions           2.506435
# avg_conversions        0.940091
# total_session             86269
# total_conversion          32357
# n_users                   34419
# Name: 21, dtype: object
#
# Sample size: 61230, Area size: 34419
# Area Zeytinburnu to be merged with next neighbor: Gaziosmanpaşa
# 24 unique areas
#
# iteration 15
# Current Smallest Area
# area_map             Beyoğlu
# avg_sessions        2.630196
# avg_conversions     1.125814
# total_session          95726
# total_conversion       40974
# n_users                36395
# Name: 5, dtype: object
#
# Sample size: 35759, Area size: 36395
# Area Beyoğlu to be merged with next neighbor: Kağıthane
# 23 unique areas
#
# iteration 16
# Current Smallest Area
# area_map            Büyükçekmece
# avg_sessions             2.53511
# avg_conversions         0.987736
# total_session             104804
# total_conversion           40834
# n_users                    41341
# Name: 6, dtype: object
#
# Sample size: 50162, Area size: 41341
# Area Büyükçekmece to be merged with next neighbor: Esenyurt
# 22 unique areas
#
# iteration 17
# Current Smallest Area
# area_map             Sarıyer
# avg_sessions        2.557746
# avg_conversions     1.072467
# total_session         108075
# total_conversion       45316
# n_users                42254
# Name: 18, dtype: object
#
# Sample size: 38108, Area size: 42254
# Area Sarıyer to be merged with next neighbor: Eyüp
# 21 unique areas
#
# iteration 18
# Current Smallest Area
# area_map            Küçükçekmece
# avg_sessions            2.399069
# avg_conversions         0.831199
# total_session             107176
# total_conversion           37133
# n_users                    44674
# Name: 14, dtype: object
#
# Sample size: 80239, Area size: 44674
# Area Küçükçekmece to be merged with next neighbor: Basaksehir
# 20 unique areas
#
# iteration 19
# Current Smallest Area
# area_map            Ümraniye
# avg_sessions        2.369992
# avg_conversions      0.84064
# total_session         114172
# total_conversion       40497
# n_users                48174
# Name: 17, dtype: object
#
# Sample size: 77106, Area size: 48174
# Area Ümraniye to be merged with next neighbor: Üsküdar
# 19 unique areas
#
# iteration 20
# Current Smallest Area
# area_map               Fatih
# avg_sessions        2.314366
# avg_conversions     0.790023
# total_session         123358
# total_conversion       42109
# n_users                53301
# Name: 9, dtype: object
#
# Sample size: 85435, Area size: 53301
# Area Fatih to be merged with next neighbor: Gaziosmanpaşa
# 18 unique areas
#
# iteration 21
# Current Smallest Area
# area_map             Esenler
# avg_sessions         2.22372
# avg_conversions     0.695951
# total_session         120281
# total_conversion       37644
# n_users                54090
# Name: 6, dtype: object
#
# Sample size: 119960, Area size: 54090
# Area Esenler to be merged with next neighbor: Bahçelievler
# 17 unique areas
#
# iteration 22
# Current Smallest Area
# area_map              Kartal
# avg_sessions        2.525685
# avg_conversions     0.977512
# total_session         142974
# total_conversion       55335
# n_users                56608
# Name: 10, dtype: object
#
# Sample size: 53134, Area size: 56608
# Area Kartal to be merged with next neighbor: Sancaktepe
# 16 unique areas
#
# iteration 23
# Current Smallest Area
# area_map            Atasehir
# avg_sessions        2.534086
# avg_conversions     1.063481
# total_session         159356
# total_conversion       66877
# n_users                62885
# Name: 0, dtype: object
#
# Sample size: 40722, Area size: 62885
# Area Atasehir to be merged with next neighbor: Üsküdar
# 15 unique areas
#
# iteration 24
# Current Smallest Area
# area_map            Bakırköy
# avg_sessions        2.635409
# avg_conversions     1.091022
# total_session         183970
# total_conversion       76161
# n_users                69807
# Name: 1, dtype: object
#
# Sample size: 41386, Area size: 69807
# Area Bakırköy to be merged with next neighbor: Beylikduzu
# 14 unique areas
#
# iteration 25
# Current Smallest Area
# area_map            Kağıthane
# avg_sessions         2.619154
# avg_conversions      1.070649
# total_session          192149
# total_conversion        78546
# n_users                 73363
# Name: 8, dtype: object
#
# Sample size: 43602, Area size: 73363
# Area Kağıthane to be merged with next neighbor: Şişli
# 13 unique areas
#
# iteration 26
# Current Smallest Area
# area_map                Eyüp
# avg_sessions        2.572127
# avg_conversions     1.033403
# total_session         223541
# total_conversion       89812
# n_users                86909
# Name: 5, dtype: object
#
# Sample size: 46652, Area size: 86909
# Area Eyüp to be merged with next neighbor: Basaksehir
# 12 unique areas
#
# iteration 27
# Current Smallest Area
# area_map            Esenyurt
# avg_sessions        2.525847
# avg_conversions     0.951198
# total_session         228766
# total_conversion       86150
# n_users                90570
# Name: 4, dtype: object
#
# Sample size: 59449, Area size: 90570
# Area Esenyurt to be merged with next neighbor: Beylikduzu
# 11 unique areas
#
# iteration 28
# Current Smallest Area
# area_map              Pendik
# avg_sessions          2.5026
# avg_conversions     0.916285
# total_session         241576
# total_conversion       88449
# n_users                96530
# Name: 7, dtype: object
#
# Sample size: 69210, Area size: 96530
# Area Pendik to be merged with next neighbor: Sancaktepe
# 10 unique areas
#
# Sample size has been reached!

# %% [markdown]
# ## Output

# %%
area_shapes.plot(column="area_name", figsize=(15,15))
# Out:
# <Axes: >

# %%
agg_shapes.plot(column="area_map", figsize=(15,15))
# Out:
# <Axes: >
