# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
import os
from qualtrics_utils import QualtricsHook

# %%
## Instantiate class
QUALTRICS_KEY = open('.env').read().split("=")[1]
qualtrics_hook = QualtricsHook(QUALTRICS_KEY)

# %% [markdown]
# # List all surveys

# %%
surveys = qualtrics_hook.get_survey_list()
surveys_df = pd.DataFrame(surveys)

# %% [markdown]
# ###

# %%
surveys_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            257 non-null    object
#  1   name          257 non-null    object
#  2   ownerId       257 non-null    object
#  3   lastModified  257 non-null    object
#  4   creationDate  257 non-null    object
#  5   isActive      257 non-null    bool
# dtypes: bool(1), object(5)
# memory usage: 10.4+ KB

# %%
survey_df_2022 = (surveys_df
            # .query("creationDate >= '2021-01-01'")
            .loc[lambda df: df.name.str.contains("VW"), :]
            .set_index("id", drop=True)
)


survey_id_list = (survey_df_2022
            .index
            .tolist()
            )

# %% [markdown]
# # Fetch Survey Data

# %%
for i,survey_id in enumerate(survey_id_list):
    print(f"{i+1} out of {len(survey_id_list)}")
    qualtrics_hook.get_survey_data(survey_id)
# Out:
# 1 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 2 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 3 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 4 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 5 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 6 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 7 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 8 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 9 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 10 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 11 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 12 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 13 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 14 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 15 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 16 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 17 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 18 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 19 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 20 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 21 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 22 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 23 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 24 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 25 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 26 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 27 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 28 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 29 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 30 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 31 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 32 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 33 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 34 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 35 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 36 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 37 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 38 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 39 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 40 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 41 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 42 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 43 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 44 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 45 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 46 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 47 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 48 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 49 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 50 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 51 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 52 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 53 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 54 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 55 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 56 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 57 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 58 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 59 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 60 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 61 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 62 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 63 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 64 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 65 out of 228
# In Progress, check again in 30...
# 66 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 67 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 68 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 69 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 70 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 71 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 72 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 73 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 74 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 75 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 76 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 77 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 78 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 79 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 80 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 81 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 82 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 83 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 84 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 85 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 86 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 87 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 88 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 89 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 90 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 91 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 92 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 93 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 94 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 95 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 96 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 97 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 98 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 99 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 100 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 101 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 102 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 103 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 104 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 105 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 106 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 107 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 108 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 109 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 110 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 111 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 112 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 113 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 114 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 115 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 116 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 117 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 118 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 119 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 120 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 121 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 122 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 123 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 124 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 125 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 126 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 127 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 128 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 129 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 130 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 131 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 132 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 133 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 134 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 135 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 136 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 137 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 138 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 139 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 140 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 141 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 142 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 143 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 144 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 145 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 146 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 147 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 148 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 149 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 150 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 151 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 152 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 153 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 154 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 155 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 156 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 157 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 158 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 159 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 160 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 161 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 162 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 163 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 164 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 165 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 166 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 167 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 168 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 169 out of 228
# 170 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 171 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 172 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 173 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 174 out of 228
# 175 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 176 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 177 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 178 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 179 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 180 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 181 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 182 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 183 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 184 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 185 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 186 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 187 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 188 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 189 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 190 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 191 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 192 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 193 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 194 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 195 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 196 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 197 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 198 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 199 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 200 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 201 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 202 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 203 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 204 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 205 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 206 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 207 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 208 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 209 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 210 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 211 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 212 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 213 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 214 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 215 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 216 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 217 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 218 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 219 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 220 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 221 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 222 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 223 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 224 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 225 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 226 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 227 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...
# 228 out of 228
# In Progress, check again in 30...
# In Progress, check again in 30...

# %% [markdown]
# # Load to GSC
#
# https://github.com/deliveryhero/datahub-airflow/blob/main/dags/gcc_service/operators/qualtrics/qualtrics_to_gcs.py

# %%
import os
from google.cloud import bigquery
from dateutil.parser import parse as parse_datetime
import json
from collections import OrderedDict
import ijson
import decimal

# %%
class JSONEncoder(json.JSONEncoder):
    def default(self, o):
        if isinstance(o, decimal.Decimal):
            return str(o)
        return super().default(o)

# %%
class QualtricsToBigQuery:
    qualtrics_dump_dir: str = "qualtric_dump"
    qualtrics_to_bq: str = "qualtrics_to_bq"
    qualtrics_bad_file:str = "qualtrics_bad_files"
    survey_type:str = "global_pricing"
    file_id:str = None
    project_table_id:str = "dh-logistics-product-ops"
    dataset_id:str = "pricing"
    table_id:str = "_dl_pricing_qualtrics_survey_export"

    def __init__(self, json_credentials, project_id):
        self.json_credentials = json_credentials
        os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = self.json_credentials
        self.bq_client = bigquery.Client(project=project_id)
        self._load_job_config()

    def _process_responses(self, survey_id:str, filename:str):
        file_path = os.path.join(self.qualtrics_dump_dir, f"{filename}.json")
        save_file = os.path.join(self.qualtrics_to_bq, f"{filename}.json")

        with open(save_file, 'w', encoding="utf8") as current_file:

            json_decoded = ijson.items(open(file_path, "rb"), 'responses.item')

            counter = 0
            for row in json_decoded:
                created_at = parse_datetime(row["values"]["startDate"])
                try:
                    payload = json.dumps(row, ensure_ascii=False, cls=JSONEncoder)
                except Exception as e:
                    print(f"Failed to parse: {row}")
                    raise e

                json_line = OrderedDict({
                    "survey_id": survey_id,
                    "survey_type": self.survey_type,
                    "response_id": row["responseId"],
                    "file_id": self.file_id,
                    "created_date": created_at.strftime("%Y-%m-%d"),
                    "created_at": created_at.strftime("%Y-%m-%dT%H:%M:%S.%fZ"),
                    "payload": payload,
                })
                current_file.write(json.dumps(json_line, ensure_ascii=False) + "\n")
                counter += 1

        # load file to bq
        if counter > 1:
            print(f"Received {counter} records.")
            self._load_to_bq(save_file)
        else:
            bad_file_path = os.path.join(self.qualtrics_bad_file, f"{filename}.json")
            print(f"Skipping downstream tasks because the survey does not contain records.")
            # print(save_file)
            os.rename(save_file, bad_file_path)
        
    
    def _load_job_config(self):
        self.job_config = bigquery.LoadJobConfig()
        self.job_config.source_format = bigquery.SourceFormat.NEWLINE_DELIMITED_JSON
        self.job_config.autodetect = True
        self.job_config.create_disposition = "CREATE_IF_NEEDED"
        self.job_config.write_disposition = "WRITE_APPEND"

    def _load_to_bq(self, file_path):
        # file_path = os.path.join(self.qualtrics_to_bq, f"{filename}.json")
        with open(file_path, "rb") as source_file:
            job = self.bq_client.load_table_from_file(
                source_file,
                f"{self.project_table_id}.{self.dataset_id}.{self.table_id}",
                job_config=self.job_config,
            )
        job.result()
        print("Loaded {} rows into {}:{}.".format(job.output_rows, self.dataset_id, self.table_id))
                

    def execute(self, survey_id, survey_filename):
        self._process_responses(survey_id, survey_filename)

# %%
survey_map = (
    survey_df_2022
    ["name"]
    .to_dict()
)

test_survey_id = 'SV_0Gmk2jVLdnKGKZ7'

qualtrics_operator = QualtricsToBigQuery(
    project_id="logistics-data-staging-flat"
    , json_credentials="/Users/s.lafaurie/.config/gcloud/application_default_credentials.json"
)

# qualtrics_op.execute(test_survey_id, survey_map[test_survey_id])
# Out:
# /Users/s.lafaurie/opt/anaconda3/envs/eda_env/lib/python3.10/site-packages/google/auth/_default.py:83: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
# remove files already loaded
survey_map_filtered = {x:y for x,y in survey_map.items() if f'{y}.json' not in os.listdir("qualtrics_to_bq")}
len_surveys = len(survey_map_filtered.keys())
len_surveys
# Out:
# 34

# %%
i=1
for survey_id, filename in survey_map_filtered.items():
    print(f"loading {survey_id}, {filename}, {i} of {len_surveys}")
    qualtrics_operator.execute(survey_id, filename)
    i += 1
# Out:
# loading SV_0TfeDHfvx25AtkG, DF VW UAE Talabat Shops Feb'22, 1 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW UAE Talabat Shops Feb'22.json
# loading SV_2cpx6wZn3G6lSzs, VW Pricing Template Q2 2022, 2 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/VW Pricing Template Q2 2022.json
# loading SV_3IeqSWazFc7LZxc, DF VW Restaurants Saudi Arabia Template, 3 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW Restaurants Saudi Arabia Template.json
# loading SV_3jDT8odisPxSUlw, DF VW South Korea Food Panda Aug'21_Input Box, 4 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW South Korea Food Panda Aug'21_Input Box.json
# loading SV_4YfYMhsXBZbqI17, DF VW Panama Dec'20, 5 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW Panama Dec'20.json
# loading SV_5oLIGRKhUfVgvjL, DF VW Panama Nov'20, 6 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW Panama Nov'20.json
# loading SV_6Rx0kKAnZcy5fDw, Groceries VW Argentina April'21, 7 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/Groceries VW Argentina April'21.json
# loading SV_8vN4mSetkSYJg6F, DF VW Panama Dec'20, 8 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW Panama Dec'20.json
# loading SV_9YRm9i4bl9MZeoB, DF VW Oman Mar'20, 9 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW Oman Mar'20.json
# loading SV_9zyZ5RfTI3qSoE6, DF VW Bolivia Feb'22 - Restaurants, 10 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW Bolivia Feb'22 - Restaurants.json
# loading SV_a44BRsJBixjtX4q, DF VW UAE Talabat Tmarts Jun'22, 11 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW UAE Talabat Tmarts Jun'22.json
# loading SV_aeFqDexTRvKgdqB, DF VW Kuwait Mar'20, 12 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW Kuwait Mar'20.json
# loading SV_blVVXeoAfk2ZuWq, DF VW El Salvador Oct'21, 13 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW El Salvador Oct'21.json
# loading SV_cBanjX1i7ccOKA5, DF VW Bahrain Mar'20, 14 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW Bahrain Mar'20.json
# loading SV_cFRyq21Nmloq0ZM, VW Chile Feb'21, 15 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/VW Chile Feb'21.json
# loading SV_ebakCcymFjW9b38, VW PeYa Restaurants Template, 16 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/VW PeYa Restaurants Template.json
# loading SV_egJpgFGObbihasK, DF VW Nicaragua Oct'21, 17 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW Nicaragua Oct'21.json
# loading SV_ehzbdztSRjC82fX, DF VW Finland Foodora Apr'20, 18 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW Finland Foodora Apr'20.json
# loading SV_0SoHWPkrWJOEqaO, VW Austria - Restaurants, 19 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/VW Austria - Restaurants.json
# loading SV_1zCx1crA7CCETKC, VW Denmark - Restaurants, 20 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/VW Denmark - Restaurants.json
# loading SV_3HQURiad7evIBLM, VW Norway - Restaurants, 21 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/VW Norway - Restaurants.json
# loading SV_3sEnJzMOUNGKvb0, DF VW Bahrain Talabat Restaurants Nov'22, 22 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW Bahrain Talabat Restaurants Nov'22.json
# loading SV_50BCCYibwS6Grci, DF VW Bahrain Talabat Shops Jan'23, 23 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW Bahrain Talabat Shops Jan'23.json
# loading SV_5c3xxwtbBDBAMXs, DF VW Oman Talabat Restaurants Nov'22, 24 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW Oman Talabat Restaurants Nov'22.json
# loading SV_7R21hK2UEfmROeO, DF VW Egypt Talabat Shops Jan'23, 25 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW Egypt Talabat Shops Jan'23.json
# loading SV_7VxqLMhWdMcD0qy, DF VW Kuwait Talabat Restaurants Nov'22, 26 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW Kuwait Talabat Restaurants Nov'22.json
# loading SV_9WvV0t4IK5ILlQO, VW Slovakia - Restaurants, 27 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/VW Slovakia - Restaurants.json
# loading SV_a5HVUYp5PvHZd7U, VW Czech - Restaurants, 28 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/VW Czech - Restaurants.json
# loading SV_aVkxqN1LFiQwXzg, DF VW UAE Talabat Restaurants Nov'22, 29 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW UAE Talabat Restaurants Nov'22.json
# loading SV_b8booVCGtYqzmn4, DF VW Qatar Talabat Restaurants Nov'22, 30 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW Qatar Talabat Restaurants Nov'22.json
# loading SV_d0yVs4YIoK5ns46, VW Finland - Restaurants, 31 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/VW Finland - Restaurants.json
# loading SV_dd59h5TvhF2wghE, VW Greece - Restaurants, 32 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/VW Greece - Restaurants.json
# loading SV_erjvUaXMy7ghyLQ, DF VW Iraq Talabat Restaurants Nov'22, 33 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW Iraq Talabat Restaurants Nov'22.json
# loading SV_esQOkUBAAQnvGDA, DF VW UAE Talabat Dmarts Jan'23, 34 of 34
# Skipping downstream tasks because the survey does not contain records.
# qualtrics_to_bq/DF VW UAE Talabat Dmarts Jan'23.json

# %% [markdown]
# #  Qualtrics DL to CL cleaning

# %%
survey_names_in_bq = [ x.split(".")[0] for x in os.listdir("qualtrics_to_bq")]
(
    surveys_df
    [surveys_df.name.isin(survey_names_in_bq)]
    .sort_values(by="creationDate")
    .get(["id", "name"])
    .to_csv("survey_ids_in_qualtrics.csv", index=False)
)


# surveys_df
